# %% [markdown]
# <a href="https://colab.research.google.com/github/Abduba011/moringa_data_science_prep_week3_independent_project_2022_04_abduba_galgalo_datareport/blob/main/Moringa_Data_Science_Prep__Independent_Project_Week4_2022_04_Abduba_Galgalo_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
#  AN ELECTRIC CAR-SHARING SERVICE COMPANY
#  Is a community based  company and platform ,providing electric vehicles as an exclusive amenity to apartments ,hotels and workplaces.They are conveniently located on property with dedicated parking spaces and can be reserved through the Electric Car sharing App.
#  The following Dataset will guide us through research questions for the company:
#
#  a).The dataset[[link text](http://bit.ly/autolib_dataset)]
#
#  b).The Data description [[link text](https://drive.google.com/a/moringaschool.com/file/d/13DXF2CFWQLeYxxHFekng8HJnH_jtbfpN/view?usp=sharing)]
#
#  THE RESEARCH QUESTION:
#
#  1.Identify the most popular hour of the day for picking up a shared electric car (Blue-Car) in the city over the month of April 2018.
#
#  2.What is the most popular hour for the Returning Cars?
#
#  3.What station is the most popular and at the most popular picking hour?
#
#  4.What postal code is the most popular for picking up Blue-Car ? and whether the most popular station belong to that postal code? and the most popular picking hour?
#
#  5.Whether the results changes if consindering Utilib and Utilib 1.4 instead of Blue-Car?

# %%
#Import the libraries to be used 
import pandas as pd

# %%
#loading and reading the data set from csv file 
#
df = pd.read_csv('http://bit.ly/autolib_dataset')
df.head()
# Out:
#                               Address  Cars  Bluecar counter  Utilib counter  \
# 0                 2 Avenue de Suffren     0                0               0
# 1           145 Rue Raymond Losserand     6                6               0
# 2    2 Avenue John Fitzgerald Kennedy     3                3               0
# 3              51 Rue Eug̬ne Oudin̩     3                3               1
# 4  6 avenue de la Porte de Champerret     3                3               0
#
#    Utilib 1.4 counter  Charge Slots Charging Status        City  \
# 0                   0             0     nonexistent       Paris
# 1                   0             0     operational       Paris
# 2                   2             0     operational  Le Bourget
# 3                   0             1     operational       Paris
# 4                   0             0     nonexistent       Paris
#
#   Displayed comment                                 ID  ... Scheduled at  \
# ...

# %%
#previewing the dataset
#
df.head(10)
# Out:
#                               Address  Cars  Bluecar counter  Utilib counter  \
# 0                 2 Avenue de Suffren     0                0               0
# 1           145 Rue Raymond Losserand     6                6               0
# 2    2 Avenue John Fitzgerald Kennedy     3                3               0
# 3              51 Rue Eug̬ne Oudin̩     3                3               1
# 4  6 avenue de la Porte de Champerret     3                3               0
# 5                8 Boulevard Voltaire     0                0               0
# 6                      37 rue Leblanc     0                0               0
# 7         17 Rue des Luaps Prolong̩e     3                3               1
# 8               34 avenue Jean Moulin     1                1               0
# 9        41 boulevard de Rochechouart     6                6               0
#
#    Utilib 1.4 counter  Charge Slots Charging Status        City  \
# ...

# %%
#accessing information about the dataset
#
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 25 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Address              5000 non-null   object
#  1   Cars                 5000 non-null   int64
#  2   Bluecar counter      5000 non-null   int64
#  3   Utilib counter       5000 non-null   int64
#  4   Utilib 1.4 counter   5000 non-null   int64
#  5   Charge Slots         5000 non-null   int64
#  6   Charging Status      5000 non-null   object
#  7   City                 5000 non-null   object
#  8   Displayed comment    111 non-null    object
#  9   ID                   5000 non-null   object
#  10  Kind                 5000 non-null   object
#  11  Geo point            5000 non-null   object
#  12  Postal code          5000 non-null   int64
#  13  Public name          5000 non-null   object
#  14  Rental status        5000 non-null   object
# ...

# %% [markdown]
# CLEANING THE DATA SET :
#  Let us perform data cleaning procedures below providing a documentation for our actions and reasons .Try to perform as many as many data cleaning procedures that suits the various dimensions of data.

# %%
#checking the validity of the data
#data cleaning action: dropping Displayed comment attribute
#Explanation : we wont need it during analysis ,no question to be answered requires that column
#
df.drop(['Displayed_Comment'], axis =1, inplace= True)
df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-5-35174d2dd455> in <module>()
#       3 #Explanation : we wont need it during analysis ,no question to be answered requires that column
#       4 #
# ----> 5 df.drop(['Displayed_Comment'], axis =1, inplace= True)
#       6 df.head()
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4911             level=level,
#    4912             inplace=inplace,
# -> 4913             errors=errors,
#    4914         )
#    4915
#
# ...

# %%
#procedure 2:Irrelevant data observation 
#data cleaning action : drop Scheduled at attributes
#
#
df.drop(['Scheduled_at'], axis = 1 , inplace =True)
df.head()
df.info()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-6-b18ed530d602> in <module>()
#       3 #
#       4 #
# ----> 5 df.drop(['Scheduled_at'], axis = 1 , inplace =True)
#       6 df.head()
#       7 df.info()
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4911             level=level,
#    4912             inplace=inplace,
# -> 4913             errors=errors,
#    4914         )
#    4915
#
# ...

# %%
#procedures 3
#data cleaning action : checking for duplicated and missing figures 
#
df.duplicated().sum()
df.isnull().sum()
# Out:
# Address                   0
# Cars                      0
# Bluecar counter           0
# Utilib counter            0
# Utilib 1.4 counter        0
# Charge Slots              0
# Charging Status           0
# City                      0
# Displayed comment      4889
# ID                        0
# Kind                      0
# Geo point                 0
# Postal code               0
# Public name               0
# Rental status             0
# Scheduled at           4953
# Slots                     0
# Station type              0
# Status                    0
# Subscription status       0
# year                      0
# month                     0
# day                       0
# hour                      0
# minute                    0
# dtype: int64

# %%
#for duplicates values 
df.duplicated().sum()
# Out:
# 0

# %%
#To check the accuracy of the datasets 
#
df.describe()
# Out:
#               Cars  Bluecar counter  Utilib counter  Utilib 1.4 counter  \
# count  5000.000000      5000.000000     5000.000000         5000.000000
# mean      2.333600         2.333600        0.059600            0.123000
# std       2.035274         2.035274        0.246698            0.356506
# min       0.000000         0.000000        0.000000            0.000000
# 25%       0.000000         0.000000        0.000000            0.000000
# 50%       2.000000         2.000000        0.000000            0.000000
# 75%       4.000000         4.000000        0.000000            0.000000
# max       7.000000         7.000000        2.000000            3.000000
#
#        Charge Slots   Postal code        Slots    year   month          day  \
# count   5000.000000   5000.000000  5000.000000  5000.0  5000.0  5000.000000
# mean       0.253400  82634.878400     1.932400  2018.0     4.0     4.941600
# std        0.546304   8835.865721     1.905402     0.0     0.0     2.597063
# ...

# %% [markdown]
# EXPORTING THE CLEANED DATASET

# %%
#let's export our dataframe into a csv file 
#daframe .to_csv('Autolib2').
#the above daframe is the dataframe which we would like to export .
#I used the to_csv function to create a csv file with the name Autolib2
#and export it 
#
df.to_csv('Autolib2')
df
# Out:
#                                  Address  Cars  Bluecar counter  \
# 0                    2 Avenue de Suffren     0                0
# 1              145 Rue Raymond Losserand     6                6
# 2       2 Avenue John Fitzgerald Kennedy     3                3
# 3                 51 Rue Eug̬ne Oudin̩     3                3
# 4     6 avenue de la Porte de Champerret     3                3
# ...                                  ...   ...              ...
# 4995                 8 avenue M̩nelotte     2                2
# 4996                   37 rue de Dantzig     4                4
# 4997                      142 rue du Bac     1                1
# 4998         2 avenue du Val de Fontenay     2                2
# 4999                 5 Rue Henry Brisson     4                4
#
#       Utilib counter  Utilib 1.4 counter  Charge Slots Charging Status  \
# 0                  0                   0             0     nonexistent
# ...

# %%
#identify the most popular hour of the day for picking up
# a shared electric car (Blue_Car) in the city over the month of april 2018
#
#
df.describe()
df.head(20)
# Out:
#                                Address  Cars  Bluecar counter  Utilib counter  \
# 0                  2 Avenue de Suffren     0                0               0
# 1            145 Rue Raymond Losserand     6                6               0
# 2     2 Avenue John Fitzgerald Kennedy     3                3               0
# 3               51 Rue Eug̬ne Oudin̩     3                3               1
# 4   6 avenue de la Porte de Champerret     3                3               0
# 5                 8 Boulevard Voltaire     0                0               0
# 6                       37 rue Leblanc     0                0               0
# 7          17 Rue des Luaps Prolong̩e     3                3               1
# 8                34 avenue Jean Moulin     1                1               0
# 9         41 boulevard de Rochechouart     6                6               0
# 10                      14 rue Censier     0                0               0
# ...

# %% [markdown]
# The popular hour for picking the Blue-Cars is 22 hrs 58 min

# %%
#what is the most popular hour for returning cars?
#
#
df.describe()
df.info()
df.head(20)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 25 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Address              5000 non-null   object
#  1   Cars                 5000 non-null   int64
#  2   Bluecar counter      5000 non-null   int64
#  3   Utilib counter       5000 non-null   int64
#  4   Utilib 1.4 counter   5000 non-null   int64
#  5   Charge Slots         5000 non-null   int64
#  6   Charging Status      5000 non-null   object
#  7   City                 5000 non-null   object
#  8   Displayed comment    111 non-null    object
#  9   ID                   5000 non-null   object
#  10  Kind                 5000 non-null   object
#  11  Geo point            5000 non-null   object
#  12  Postal code          5000 non-null   int64
#  13  Public name          5000 non-null   object
#  14  Rental status        5000 non-null   object
# ...

# %% [markdown]
# The station with most returning cars is fontenayauxroses-jeanjaures-3

# %%
#what station is the most popular?
#
df.describe()
df.info()
df.head(20)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 25 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Address              5000 non-null   object
#  1   Cars                 5000 non-null   int64
#  2   Bluecar counter      5000 non-null   int64
#  3   Utilib counter       5000 non-null   int64
#  4   Utilib 1.4 counter   5000 non-null   int64
#  5   Charge Slots         5000 non-null   int64
#  6   Charging Status      5000 non-null   object
#  7   City                 5000 non-null   object
#  8   Displayed comment    111 non-null    object
#  9   ID                   5000 non-null   object
#  10  Kind                 5000 non-null   object
#  11  Geo point            5000 non-null   object
#  12  Postal code          5000 non-null   int64
#  13  Public name          5000 non-null   object
#  14  Rental status        5000 non-null   object
# ...

# %% [markdown]
# The most popular station is Paris jeanmoulin-34

# %%
#station at the most popular picking hour?
#
#
df.describe()
df.info()
df.head(20)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 25 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Address              5000 non-null   object
#  1   Cars                 5000 non-null   int64
#  2   Bluecar counter      5000 non-null   int64
#  3   Utilib counter       5000 non-null   int64
#  4   Utilib 1.4 counter   5000 non-null   int64
#  5   Charge Slots         5000 non-null   int64
#  6   Charging Status      5000 non-null   object
#  7   City                 5000 non-null   object
#  8   Displayed comment    111 non-null    object
#  9   ID                   5000 non-null   object
#  10  Kind                 5000 non-null   object
#  11  Geo point            5000 non-null   object
#  12  Postal code          5000 non-null   int64
#  13  Public name          5000 non-null   object
#  14  Rental status        5000 non-null   object
# ...

# %% [markdown]
# Paris-jeanmoulin-34 has the most picking hour

# %%
#what postal code is the most popular for picking the blue_car?
#
df.describe()
df.info()
df.head(20)

# %%
#does the most popular station belong to that postal code?
#
#NO
df.describe()
df.info()
df.head(20)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 25 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Address              5000 non-null   object
#  1   Cars                 5000 non-null   int64
#  2   Bluecar counter      5000 non-null   int64
#  3   Utilib counter       5000 non-null   int64
#  4   Utilib 1.4 counter   5000 non-null   int64
#  5   Charge Slots         5000 non-null   int64
#  6   Charging Status      5000 non-null   object
#  7   City                 5000 non-null   object
#  8   Displayed comment    111 non-null    object
#  9   ID                   5000 non-null   object
#  10  Kind                 5000 non-null   object
#  11  Geo point            5000 non-null   object
#  12  Postal code          5000 non-null   int64
#  13  Public name          5000 non-null   object
#  14  Rental status        5000 non-null   object
# ...

# %%
#what postal code is the most popular during picking hour ?
#
df["Postal code"].value_counts()
# Out:
# 75015    274
# 75016    236
# 75017    221
# 75011    180
# 75020    169
#         ...
# 75116      5
# 93310      4
# 91400      4
# 92110      4
# 94100      2
# Name: Postal code, Length: 107, dtype: int64

# %%
#Do the results change if Utilib and Utilib 1.4 instead of Blue_Cars?
#
#
